# %%
import numpy as np
import tensorflow as tf
import os
import cv2
import matplotlib.pyplot as plt
from keras.models import load_model

# %%
img = cv2.imread('211_100.jpg')
# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (100,100))
# plt.imshow()
# plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),resize.numpy().astype(int))

# plt.show()

# %%
model = load_model(os.path.join('models','Fruitmodel.h5'))

# %%
yhat = model.predict(np.expand_dims(resize, 0))
yhat
np.argmax(yhat)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# 12

# %%
# Out:
# 12

# %%
folder = 'fruits-360/Test'

sub_folders = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name))]

print(sub_folders[12])
# Out:
# Avocado ripe
