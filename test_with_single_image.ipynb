# %%
import numpy as np
import tensorflow as tf
import os
import cv2
import matplotlib.pyplot as plt
from keras.models import load_model

# %%
img = cv2.imread('44_100.jpg')
# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (100,100))
plt.imshow()
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),resize.numpy().astype(int))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 resize = tf.image.resize(img, (100,100))
# ----> 2 plt.imshow()
#       3 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),resize.numpy().astype(int))
#       5 plt.show()
#
# TypeError: imshow() missing 1 required positional argument: 'X'

# %%
model = load_model(os.path.join('models','Fruitmodel1.h5'))

# %%
yhat = model.predict(np.expand_dims(resize, 0))
yhat
np.argmax(yhat)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 27

# %%
folder = 'fruits-360/Test'

sub_folders = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name))]

print(sub_folders[np.argmax(yhat)])
# Out:
# Dates
